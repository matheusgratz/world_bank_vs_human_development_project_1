# %%
import pandas as pd
from sodapy import Socrata

# %%
# Unauthenticated client only works with public data sets.
client = Socrata("finances.worldbank.org", "IWNqQjLTuoqLzNuGAm5zyIV4f")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("tdwh-3krx", limit = 2000)

# Converting to pandas dataframe
results_df = pd.DataFrame.from_records(results)
results_df.head()
# Out:
#              end_of_period credit_number                       region  \
# 0  2011-04-30T00:00:00.000      IDA00010  LATIN AMERICA AND CARIBBEAN
# 1  2011-05-31T00:00:00.000      IDA00010  LATIN AMERICA AND CARIBBEAN
# 2  2011-06-30T00:00:00.000      IDA00010  LATIN AMERICA AND CARIBBEAN
# 3  2011-07-31T00:00:00.000      IDA00010  LATIN AMERICA AND CARIBBEAN
# 4  2011-08-31T00:00:00.000      IDA00010  LATIN AMERICA AND CARIBBEAN
#
#   country_code   country                                  borrower  \
# 0           HN  Honduras  MINISTERIO DE HACIENDA Y CREDITO PUBLICO
# 1           HN  Honduras  MINISTERIO DE HACIENDA Y CREDITO PUBLICO
# 2           HN  Honduras  MINISTERIO DE HACIENDA Y CREDITO PUBLICO
# 3           HN  Honduras  MINISTERIO DE HACIENDA Y CREDITO PUBLICO
# 4           HN  Honduras  MINISTERIO DE HACIENDA Y CREDITO PUBLICO
#
#   credit_status service_charge_rate currency_of_commitment project_id  ...  \
# 0  Fully Repaid                0.75                    USD    P007335  ...
# 1  Fully Repaid                0.75                    USD    P007335  ...
# 2  Fully Repaid                0.75                    USD    P007335  ...
# 3  Fully Repaid                0.75                    USD    P007335  ...
# 4  Fully Repaid                0.75                    USD    P007335  ...
#
#   sold_3rd_party repaid_3rd_party due_3rd_party credits_held  \
# 0           0.00             0.00          0.00         0.00
# 1           0.00             0.00          0.00         0.00
# 2           0.00             0.00          0.00         0.00
# 3           0.00             0.00          0.00         0.00
# 4           0.00             0.00          0.00         0.00
#
#       first_repayment_date      last_repayment_date   agreement_signing_date  \
# 0  1971-09-01T00:00:00.000  2011-03-01T00:00:00.000  1961-05-12T00:00:00.000
# 1  1971-09-01T00:00:00.000  2011-03-01T00:00:00.000  1961-05-12T00:00:00.000
# 2  1971-09-01T00:00:00.000  2011-03-01T00:00:00.000  1961-05-12T00:00:00.000
# 3  1971-09-01T00:00:00.000  2011-03-01T00:00:00.000  1961-05-12T00:00:00.000
# 4  1971-09-01T00:00:00.000  2011-03-01T00:00:00.000  1961-05-12T00:00:00.000
#
#        board_approval_date effective_date_most_recent_  \
# 0  1961-05-11T00:00:00.000     1961-06-29T00:00:00.000
# 1  1961-05-11T00:00:00.000     1961-06-29T00:00:00.000
# 2  1961-05-11T00:00:00.000     1961-06-29T00:00:00.000
# 3  1961-05-11T00:00:00.000     1961-06-29T00:00:00.000
# 4  1961-05-11T00:00:00.000     1961-06-29T00:00:00.000
#
#   closed_date_most_recent_
# 0  1967-07-31T00:00:00.000
# 1  1967-07-31T00:00:00.000
# 2  1967-07-31T00:00:00.000
# 3  1967-07-31T00:00:00.000
# 4  1967-07-31T00:00:00.000
#
# [5 rows x 29 columns]

# %%
# Removing unnecessary columns
results_df = results_df.drop(["credit_number"], axis = 1)
results_df.shape
# Out:
# (2000, 28)

# %%
results_df["credit_status"].unique()
# Out:
# array(['Fully Repaid', 'Repaid', 'Repaying', 'Disbursed'], dtype=object)
