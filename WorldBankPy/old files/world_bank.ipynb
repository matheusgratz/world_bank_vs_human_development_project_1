# %%
# Importing dependencies

import pandas as pd
from sodapy import Socrata
import warnings
warnings.filterwarnings('ignore')

# %%
# Unauthenticated client only works with public data sets.
client = Socrata("finances.worldbank.org", "IWNqQjLTuoqLzNuGAm5zyIV4f")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("tdwh-3krx", limit = 900000)

# Converting to pandas dataframe
results_df = pd.DataFrame.from_records(results)
results_df.head(3)
# Out:
# 852117

# %%
results_df.to_csv("")
# Out:
# 852117

# %%
# Removing unnecessary columns
clean_df = results_df[["credit_number", "region", "country_code", "country", "credit_status", "currency_of_commitment", 
                       "original_principal_amount", "disbursed_amount", "agreement_signing_date"]]
clean_df.head(3)
# Out:
#   credit_number                       region country_code   country  \
# 0      IDA00010  LATIN AMERICA AND CARIBBEAN           HN  Honduras
# 1      IDA00010  LATIN AMERICA AND CARIBBEAN           HN  Honduras
# 2      IDA00010  LATIN AMERICA AND CARIBBEAN           HN  Honduras
#
#   credit_status currency_of_commitment original_principal_amount  \
# 0  Fully Repaid                    USD                9000000.00
# 1  Fully Repaid                    USD                9000000.00
# 2  Fully Repaid                    USD                9000000.00
#
#   disbursed_amount   agreement_signing_date
# 0       8427973.97  1961-05-12T00:00:00.000
# 1       8427973.97  1961-05-12T00:00:00.000
# 2       8427973.97  1961-05-12T00:00:00.000

# %%
# Reviewing currencies 
currency = clean_df["currency_of_commitment"].unique()

# Reviewing regions
regions = clean_df["region"].unique()

print(currency, regions)
# Out:
# ['USD' 'XDR' 'EUR' 'JPY' 'XAF'] ['LATIN AMERICA AND CARIBBEAN' 'AFRICA' 'AFRICA EAST' 'SOUTH ASIA'
#  'EAST ASIA AND PACIFIC' 'MIDDLE EAST AND NORTH AFRICA'
#  'EUROPE AND CENTRAL ASIA' 'AFRICA WEST' 'OTHER']

# %%
clean_df.dtypes
# Out:
# credit_number                object
# region                       object
# country_code                 object
# country                      object
# credit_status                object
# currency_of_commitment       object
# original_principal_amount    object
# disbursed_amount             object
# agreement_signing_date       object
# dtype: object

# %%
# Converting columns to correct data types
clean_df["original_principal_amount"] = clean_df["original_principal_amount"].astype(float)
clean_df["disbursed_amount"] = clean_df["disbursed_amount"].astype(float)

# %%
# clean_df["agreement_signing_date2"] = clean_df["agreement_signing_date"].str.split("T")
clean_df["agreement_signing_date"] = pd.to_datetime(clean_df["agreement_signing_date"])

clean_df.head(3)
# Out:
#   credit_number                       region country_code   country  \
# 0      IDA00010  LATIN AMERICA AND CARIBBEAN           HN  Honduras
# 1      IDA00010  LATIN AMERICA AND CARIBBEAN           HN  Honduras
# 2      IDA00010  LATIN AMERICA AND CARIBBEAN           HN  Honduras
#
#   credit_status currency_of_commitment  original_principal_amount  \
# 0  Fully Repaid                    USD                  9000000.0
# 1  Fully Repaid                    USD                  9000000.0
# 2  Fully Repaid                    USD                  9000000.0
#
#    disbursed_amount agreement_signing_date
# 0        8427973.97             1961-05-12
# 1        8427973.97             1961-05-12
# 2        8427973.97             1961-05-12

# %%
clean_df["agreement_year"] = pd.DatetimeIndex(clean_df["agreement_signing_date"]).year

clean_df.head()
# Out:
#   credit_number                       region country_code   country  \
# 0      IDA00010  LATIN AMERICA AND CARIBBEAN           HN  Honduras
# 1      IDA00010  LATIN AMERICA AND CARIBBEAN           HN  Honduras
# 2      IDA00010  LATIN AMERICA AND CARIBBEAN           HN  Honduras
# 3      IDA00010  LATIN AMERICA AND CARIBBEAN           HN  Honduras
# 4      IDA00010  LATIN AMERICA AND CARIBBEAN           HN  Honduras
#
#   credit_status currency_of_commitment  original_principal_amount  \
# 0  Fully Repaid                    USD                  9000000.0
# 1  Fully Repaid                    USD                  9000000.0
# 2  Fully Repaid                    USD                  9000000.0
# 3  Fully Repaid                    USD                  9000000.0
# 4  Fully Repaid                    USD                  9000000.0
#
#    disbursed_amount agreement_signing_date  agreement_year
# 0        8427973.97             1961-05-12          1961.0
# 1        8427973.97             1961-05-12          1961.0
# 2        8427973.97             1961-05-12          1961.0
# 3        8427973.97             1961-05-12          1961.0
# 4        8427973.97             1961-05-12          1961.0

# %%
grouped_df = clean_df.groupby(["region", "country_code", "country", "agreement_year", 'currency_of_commitment']).agg(
total_original_principal_amount = ("original_principal_amount", "sum"), 
total_disbursed_amount = ("disbursed_amount", "sum"))

grouped_df
# Out:
#                                                                         total_original_principal_amount  \
# region     country_code country  agreement_year currency_of_commitment
# AFRICA     3A           Africa   2001.0         XDR                                        5.600000e+08
#                                  2004.0         XDR                                        6.720000e+08
#                                  2005.0         XDR                                        2.800000e+09
#                                  2011.0         XDR                                        7.985000e+09
#                                  2012.0         XDR                                        4.654500e+09
# ...                                                                                                 ...
# SOUTH ASIA PK           Pakistan 2017.0         XDR                                        2.658091e+10
#                                  2018.0         XDR                                        2.168330e+10
#                                  2019.0         XDR                                        1.941680e+10
#                                  2020.0         JPY                                        6.000000e+08
#                                                 XDR                                        2.939000e+09
#
#                                                                         total_disbursed_amount
# region     country_code country  agreement_year currency_of_commitment
# AFRICA     3A           Africa   2001.0         XDR                               5.947673e+08
#                                  2004.0         XDR                               5.680490e+08
#                                  2005.0         XDR                               2.859733e+09
#                                  2011.0         XDR                               6.296284e+09
#                                  2012.0         XDR                               1.473507e+09
# ...                                                                                        ...
# SOUTH ASIA PK           Pakistan 2017.0         XDR                               1.539391e+10
#                                  2018.0         XDR                               4.964706e+09
#                                  2019.0         XDR                               1.248193e+09
#                                  2020.0         JPY                               0.000000e+00
#                                                 XDR                               1.576414e+09
#
# [4485 rows x 2 columns]

# %%
grouped_df.reset_index(inplace=True)
grouped_df
# Out:
#           region country_code   country  agreement_year  \
# 0         AFRICA           3A    Africa          2001.0
# 1         AFRICA           3A    Africa          2004.0
# 2         AFRICA           3A    Africa          2005.0
# 3         AFRICA           3A    Africa          2011.0
# 4         AFRICA           3A    Africa          2012.0
# ...          ...          ...       ...             ...
# 4480  SOUTH ASIA           PK  Pakistan          2017.0
# 4481  SOUTH ASIA           PK  Pakistan          2018.0
# 4482  SOUTH ASIA           PK  Pakistan          2019.0
# 4483  SOUTH ASIA           PK  Pakistan          2020.0
# 4484  SOUTH ASIA           PK  Pakistan          2020.0
#
#      currency_of_commitment  total_original_principal_amount  \
# 0                       XDR                     5.600000e+08
# 1                       XDR                     6.720000e+08
# 2                       XDR                     2.800000e+09
# 3                       XDR                     7.985000e+09
# 4                       XDR                     4.654500e+09
# ...                     ...                              ...
# 4480                    XDR                     2.658091e+10
# 4481                    XDR                     2.168330e+10
# 4482                    XDR                     1.941680e+10
# 4483                    JPY                     6.000000e+08
# 4484                    XDR                     2.939000e+09
#
#       total_disbursed_amount
# 0               5.947673e+08
# 1               5.680490e+08
# 2               2.859733e+09
# 3               6.296284e+09
# 4               1.473507e+09
# ...                      ...
# 4480            1.539391e+10
# 4481            4.964706e+09
# 4482            1.248193e+09
# 4483            0.000000e+00
# 4484            1.576414e+09
#
# [4485 rows x 7 columns]

# %%
grouped_df2 = grouped_df.loc[grouped_df["agreement_year"] >= 1990]
grouped_df2
# Out:
#           region country_code   country  agreement_year  \
# 0         AFRICA           3A    Africa          2001.0
# 1         AFRICA           3A    Africa          2004.0
# 2         AFRICA           3A    Africa          2005.0
# 3         AFRICA           3A    Africa          2011.0
# 4         AFRICA           3A    Africa          2012.0
# ...          ...          ...       ...             ...
# 4480  SOUTH ASIA           PK  Pakistan          2017.0
# 4481  SOUTH ASIA           PK  Pakistan          2018.0
# 4482  SOUTH ASIA           PK  Pakistan          2019.0
# 4483  SOUTH ASIA           PK  Pakistan          2020.0
# 4484  SOUTH ASIA           PK  Pakistan          2020.0
#
#      currency_of_commitment  total_original_principal_amount  \
# 0                       XDR                     5.600000e+08
# 1                       XDR                     6.720000e+08
# 2                       XDR                     2.800000e+09
# 3                       XDR                     7.985000e+09
# 4                       XDR                     4.654500e+09
# ...                     ...                              ...
# 4480                    XDR                     2.658091e+10
# 4481                    XDR                     2.168330e+10
# 4482                    XDR                     1.941680e+10
# 4483                    JPY                     6.000000e+08
# 4484                    XDR                     2.939000e+09
#
#       total_disbursed_amount
# 0               5.947673e+08
# 1               5.680490e+08
# 2               2.859733e+09
# 3               6.296284e+09
# 4               1.473507e+09
# ...                      ...
# 4480            1.539391e+10
# 4481            4.964706e+09
# 4482            1.248193e+09
# 4483            0.000000e+00
# 4484            1.576414e+09
#
# [3021 rows x 7 columns]

# %%
# Copying results to a csv file
grouped_df.to_csv("data.csv")
